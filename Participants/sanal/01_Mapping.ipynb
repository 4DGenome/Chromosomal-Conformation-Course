# %%
r_enz='HindIII'

# %%
from pytadbit.mapping.full_mapper import full_mapping

# %%
! mkdir -p results

# %%
! mkdir -p results/HindIII

# %%
! mkdir -p results/HindIII/01_mapping

# %%
! mkdir -p results/MboI

# %%
! mkdir -p results/MboI/01_mapping

# %%
full_mapping('media/storage/db/reference_genome/Homo_sapiens/hg38/hg38.gem', nthreads=2, 
            clean=True, r_enz=r_enz, frag_map=False, 
            out_map_dir='results/{0}/01_mapping/map{0}_r1'.format(r_enz), 
            fastq_path='/media/storage/FASTQs/K562_{0}_1.fastq'.format(r_enz), 
            windows=((1,25), (1,30), (1,40), (1,75)))
# Out:
# Preparing FASTQ file
#   - conversion to MAP format
#   - trimming reads 1-25
# Mapping reads in window 1-25...
# TO GEM /home/student/tmp/K562_HindIII_1_bMPcNn
# /usr/local/bin/gem-mapper -I /media/storage/Notebooks2/sanal/media/storage/db/reference_genome/Homo_sapiens/hg38/hg38.gem -q offset-33 -m 0.04 -s 0 --allow-incomplete-strata 0.00 --granularity 10000 --max-decoded-matches 1 --min-decoded-strata 0 --min-insert-size 0 --max-insert-size 0 --min-matched-bases 0.8 --gem-quality-threshold 26 --max-big-indel-length 15 --mismatch-alphabet ACGT -E 0.30 --max-extendable-matches 20 --max-extensions-per-match 1 -e 0.04 -T 2 -i /home/student/tmp/K562_HindIII_1_bMPcNn -o /home/student/tmp/K562_HindIII_1_bMPcNn_full_1-25
# Parsing result...
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-16-32d27d136b2e> in <module>()
#       3             out_map_dir='results/{0}/01_mapping/map{0}_r1'.format(r_enz),
#       4             fastq_path='/media/storage/FASTQs/K562_{0}_1.fastq'.format(r_enz),
# ----> 5             windows=((1,25), (1,30), (1,40), (1,75)))
#       6
#
# /home/student/.miniconda2/lib/python2.7/site-packages/pytadbit/mapping/full_mapper.pyc in full_mapping(gem_index_path, fastq_path, out_map_dir, r_enz, frag_map, min_seq_len, windows, add_site, clean, get_nread, **kwargs)
#     442                         os.path.join(out_map_dir,
#     443                                      base_name + '_full_%s-%s%s.map' % (
# --> 444                                          beg, end, suffix)))
#     445             # clean
#     446             if clean:
#
# /home/student/.miniconda2/lib/python2.7/site-packages/pytadbit/mapping/full_mapper.pyc in _gem_filter(fnam, unmap_out, map_out)
#     216        - not feasible with gt.filter
#     217     """
# --> 218     fhandler = magic_open(fnam) if isinstance(fnam, str) else fnam
#     219     unmap_out = open(unmap_out, 'w')
#     220     map_out   = open(map_out  , 'w')
#
# /home/student/.miniconda2/lib/python2.7/site-packages/pytadbit/utils/file_handling.pyc in magic_open(filename, verbose, cpus)
#      27     """
#      28     if isinstance(filename, str) or isinstance(filename, unicode):
# ---> 29         fhandler = file(filename, 'rb')
#      30         inputpath = True
#      31         if tarfile.is_tarfile(filename):
#
# IOError: [Errno 2] No such file or directory: '/home/student/tmp/K562_HindIII_1_bMPcNn_full_1-25.map'

# %%
full_mapping('media/storage/db/reference_genome/Homo_sapiens/hg38/hg38.gem', nthreads=2, 
            clean=True, r_enz=r_enz, frag_map=False, out_map_dir='results/{0}/01_mapping/map{0}_r2'.format(r_enz), 
            fastq_path='/media/storage/FASTQs/K562_{0}_2.fastq'.format(r_enz), windows=((1,25), (1,30), (1,40), (1,75)))

# %%
full_mapping('media/storage/db/reference_genome/Homo_sapiens/hg38/hg38.gem', nthreads=2, 
            clean=True, r_enz=r_enz, frag_map=True, out_map_dir='results/{0}/01_mapping/map{0}_r1'.format(r_enz), 
            fastq_path='/media/storage/FASTQs/K562_{0}_1.fastq'.format(r_enz))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-26-8d07a390d90b> in <module>()
#       1 full_mapping('media/storage/db/reference_genome/Homo_sapiens/hg38/hg38.gem', nthreads=2,
#       2             clean=True, r_enz=r_enz, frag_map=True, out_map_dir='results/{0}/01_mapping/map{0}_r1'.format(r_enz),
# ----> 3             fastq_path='/media/storage/FASTQs/K562_{0}_1.fastq'.format(r_enz))
#
# /home/student/.miniconda2/lib/python2.7/site-packages/pytadbit/mapping/full_mapper.pyc in full_mapping(gem_index_path, fastq_path, out_map_dir, r_enz, frag_map, min_seq_len, windows, add_site, clean, get_nread, **kwargs)
#     384     # create directories
#     385     for rep in [temp_dir, out_map_dir]:
# --> 386         mkdir(rep)
#     387     # check space
#     388     fspace = int(get_free_space_mb(temp_dir, div=3))
#
# /home/student/.miniconda2/lib/python2.7/site-packages/pytadbit/utils/file_handling.pyc in mkdir(dnam)
#     100 def mkdir(dnam):
#     101     try:
# --> 102         os.mkdir(dnam)
#     103     except OSError as exc:
#     104         if exc.errno == errno.EEXIST and os.path.isdir(dnam):
#
# OSError: [Errno 2] No such file or directory: 'results/HindIII/01_mapping/mapHindIII_r1'

# %%
ls
# Out:
# 00_fstq_QC.ipynb  learning_python.ipynb  text2.txt
# 01_Mapping.ipynb  results/               text.txt

# %%
ls
# Out:
# 00_fstq_QC.ipynb  learning_python.ipynb  text2.txt
# 01_Mapping.ipynb  results/               text.txt

# %%
cd ..
# Out:
# /media/storage/Notebooks2

# %%
ls
# Out:
# agnese/   deo/     fabio/    JCarlos/  marta/   sanal/
# Alberto/  eralda/  fransua@  Jordi/    mon/     stephi/
# Debora/   evidal@  Gaetano/  mariya/   myname/

# %%
cd sanal
# Out:
# /media/storage/Notebooks2/sanal

# %%
ls
# Out:
# 00_fstq_QC.ipynb  learning_python.ipynb  text2.txt
# 01_Mapping.ipynb  results/               text.txt

# %%
cd results
# Out:
# /media/storage/Notebooks2/sanal/results

# %%
ls
# Out:
# HindIII/  MboI/

# %%
cd ..
# Out:
# /media/storage/Notebooks2/sanal

# %%
full_mapping('/media/storage/db/reference_genome/Homo_sapiens/hg38/hg38.gem', nthreads=2, 
            clean=True, r_enz=r_enz, frag_map=True, out_map_dir='results/{0}/01_mapping/map{0}_r1'.format(r_enz), 
            fastq_path='/media/storage/FASTQs/K562_{0}_1.fastq'.format(r_enz))
# Out:
# /home/student/.miniconda2/lib/python2.7/site-packages/pytadbit/mapping/full_mapper.py:390: UserWarning: WARNING: only 71 Gb left on tmp_dir: /home/student/tmp
#
#   warn('WARNING: only %d Gb left on tmp_dir: %s\n' % (fspace, temp_dir))
# Preparing FASTQ file
#   - conversion to MAP format
# Mapping reads in window 1-end...
# TO GEM /home/student/tmp/K562_HindIII_1_VJtw43
# /usr/local/bin/gem-mapper -I /media/storage/db/reference_genome/Homo_sapiens/hg38/hg38.gem -q offset-33 -m 0.04 -s 0 --allow-incomplete-strata 0.00 --granularity 10000 --max-decoded-matches 1 --min-decoded-strata 0 --min-insert-size 0 --max-insert-size 0 --min-matched-bases 0.8 --gem-quality-threshold 26 --max-big-indel-length 15 --mismatch-alphabet ACGT -E 0.30 --max-extendable-matches 20 --max-extensions-per-match 1 -e 0.04 -T 2 -i /home/student/tmp/K562_HindIII_1_VJtw43 -o /home/student/tmp/K562_HindIII_1_VJtw43_full_1-end
# Parsing result...
#    x removing GEM input /home/student/tmp/K562_HindIII_1_VJtw43
#    x removing map /home/student/tmp/K562_HindIII_1_VJtw43_full_1-end.map
#   - splitting into restriction enzyme (RE) fragments using ligation sites
#   - ligation sites are replaced by RE sites to match the reference genome
#     * enzyme: HindIII, ligation site: AAGCTAGCTT, RE site: AAGCTT
# Preparing MAP file
#    x removing pre-GEM input /home/student/tmp/K562_HindIII_1_VJtw43_filt_1-end.map
# Mapping fragments of remaining reads...
# TO GEM /home/student/tmp/K562_HindIII_1_uMYuDx
# /usr/local/bin/gem-mapper -I /media/storage/db/reference_genome/Homo_sapiens/hg38/hg38.gem -q offset-33 -m 0.04 -s 0 --allow-incomplete-strata 0.00 --granularity 10000 --max-decoded-matches 1 --min-decoded-strata 0 --min-insert-size 0 --max-insert-size 0 --min-matched-bases 0.8 --gem-quality-threshold 26 --max-big-indel-length 15 --mismatch-alphabet ACGT -E 0.30 --max-extendable-matches 20 --max-extensions-per-match 1 -e 0.04 -T 2 -i /home/student/tmp/K562_HindIII_1_uMYuDx -o /home/student/tmp/K562_HindIII_1_uMYuDx_frag_1-end
# Parsing result...
#    x removing GEM input /home/student/tmp/K562_HindIII_1_uMYuDx
#    x removing failed to map /home/student/tmp/K562_HindIII_1_VJtw43_fail.map
#    x removing tmp mapped /home/student/tmp/K562_HindIII_1_uMYuDx_frag_1-end.map
# ['results/HindIII/01_mapping/mapHindIII_r1/K562_HindIII_1_full_1-end.map',
#  'results/HindIII/01_mapping/mapHindIII_r1/K562_HindIII_1_frag_1-end.map']

# %%
full_mapping('/media/storage/db/reference_genome/Homo_sapiens/hg38/hg38.gem', nthreads=2, 
            clean=True, r_enz=r_enz, frag_map=True, out_map_dir='results/{0}/01_mapping/map{0}_r2'.format(r_enz), 
            fastq_path='/media/storage/FASTQs/K562_{0}_2.fastq'.format(r_enz))
# Out:
# /home/student/.miniconda2/lib/python2.7/site-packages/pytadbit/mapping/full_mapper.py:390: UserWarning: WARNING: only 69 Gb left on tmp_dir: /home/student/tmp
#
#   warn('WARNING: only %d Gb left on tmp_dir: %s\n' % (fspace, temp_dir))
# Preparing FASTQ file
#   - conversion to MAP format
# Mapping reads in window 1-end...
# TO GEM /home/student/tmp/K562_HindIII_2_TtGPtZ
# /usr/local/bin/gem-mapper -I /media/storage/db/reference_genome/Homo_sapiens/hg38/hg38.gem -q offset-33 -m 0.04 -s 0 --allow-incomplete-strata 0.00 --granularity 10000 --max-decoded-matches 1 --min-decoded-strata 0 --min-insert-size 0 --max-insert-size 0 --min-matched-bases 0.8 --gem-quality-threshold 26 --max-big-indel-length 15 --mismatch-alphabet ACGT -E 0.30 --max-extendable-matches 20 --max-extensions-per-match 1 -e 0.04 -T 2 -i /home/student/tmp/K562_HindIII_2_TtGPtZ -o /home/student/tmp/K562_HindIII_2_TtGPtZ_full_1-end
# Parsing result...
#    x removing GEM input /home/student/tmp/K562_HindIII_2_TtGPtZ
#    x removing map /home/student/tmp/K562_HindIII_2_TtGPtZ_full_1-end.map
#   - splitting into restriction enzyme (RE) fragments using ligation sites
#   - ligation sites are replaced by RE sites to match the reference genome
#     * enzyme: HindIII, ligation site: AAGCTAGCTT, RE site: AAGCTT
# Preparing MAP file
#    x removing pre-GEM input /home/student/tmp/K562_HindIII_2_TtGPtZ_filt_1-end.map
# Mapping fragments of remaining reads...
# TO GEM /home/student/tmp/K562_HindIII_2_Qp8keF
# /usr/local/bin/gem-mapper -I /media/storage/db/reference_genome/Homo_sapiens/hg38/hg38.gem -q offset-33 -m 0.04 -s 0 --allow-incomplete-strata 0.00 --granularity 10000 --max-decoded-matches 1 --min-decoded-strata 0 --min-insert-size 0 --max-insert-size 0 --min-matched-bases 0.8 --gem-quality-threshold 26 --max-big-indel-length 15 --mismatch-alphabet ACGT -E 0.30 --max-extendable-matches 20 --max-extensions-per-match 1 -e 0.04 -T 2 -i /home/student/tmp/K562_HindIII_2_Qp8keF -o /home/student/tmp/K562_HindIII_2_Qp8keF_frag_1-end
# Parsing result...
#    x removing GEM input /home/student/tmp/K562_HindIII_2_Qp8keF
#    x removing failed to map /home/student/tmp/K562_HindIII_2_TtGPtZ_fail.map
#    x removing tmp mapped /home/student/tmp/K562_HindIII_2_Qp8keF_frag_1-end.map
# ['results/HindIII/01_mapping/mapHindIII_r2/K562_HindIII_2_full_1-end.map',
#  'results/HindIII/01_mapping/mapHindIII_r2/K562_HindIII_2_frag_1-end.map']

# %%
ls
# Out:
# 00_fstq_QC.ipynb  learning_python.ipynb  text2.txt
# 01_Mapping.ipynb  results/               text.txt

# %%
from pytadbit.parsers.genome_parser import parse_fasta

# %%
genome_seq = parse_fasta("/media/storage/db/reference_genome/Homo_sapiens/hg38/hg38.fa")
# Out:
# Parsing chr1
# Parsing chr2
# Parsing chr3
# Parsing chr4
# Parsing chr5
# Parsing chr6
# Parsing chr7
# Parsing chr8
# Parsing chr9
# Parsing chr10
# Parsing chr11
# Parsing chr12
# Parsing chr13
# Parsing chr14
# Parsing chr15
# Parsing chr16
# Parsing chr17
# Parsing chr18
# Parsing chr19
# Parsing chr20
# Parsing chr21
# Parsing chr22
# Parsing chrX
# Parsing chrY
# Parsing chrM

# %%
maps2= ['results/HindIII/01_mapping/mapHindIII_r2/K562_HindIII_2_full_1-end.map',
 'results/HindIII/01_mapping/mapHindIII_r2/K562_HindIII_2_frag_1-end.map']

# %%
ls
# Out:
# 00_fstq_QC.ipynb  learning_python.ipynb  text2.txt
# 01_Mapping.ipynb  results/               text.txt

# %%
cd /results/HindIII/
# Out:
# [Errno 2] No such file or directory: '/results/HindIII/'
# /media/storage/Notebooks2/sanal

# %%
ls
# Out:
# 00_fstq_QC.ipynb  learning_python.ipynb  text2.txt
# 01_Mapping.ipynb  results/               text.txt

# %%
cd results
# Out:
# /media/storage/Notebooks2/sanal/results

# %%
cd HindIII
# Out:
# /media/storage/Notebooks2/sanal/results/HindIII

# %%
ll
# Out:
# total 8
# drwxrwxr-x 4 student 4096 Apr  4 17:48 01_mapping/
# drwxrwxr-x 2 student 4096 Apr  5 18:20 02_parsing/

# %%
cd 02_parsing/
# Out:
# /media/storage/Notebooks2/sanal/results/HindIII/02_parsing

# %%
ll
# Out:
# total 1642744
# -rw-rw-r-- 1 student 855468246 Apr  6 15:11 reads1_HindIII.tsv
# -rw-rw-r-- 1 student 826687843 Apr  6 15:11 reads2_HindIII.tsv

# %%
! head -n 50 reads2_HindIII.tsv
# Out:
# # Chromosome lengths (order matters):
# # CRM chr1	248956422
# # CRM chr2	242193529
# # CRM chr3	198295559
# # CRM chr4	190214555
# # CRM chr5	181538259
# # CRM chr6	170805979
# # CRM chr7	159345973
# # CRM chr8	145138636
# # CRM chr9	138394717
# # CRM chr10	133797422
# # CRM chr11	135086622
# # CRM chr12	133275309
# # CRM chr13	114364328
# # CRM chr14	107043718
# # CRM chr15	101991189
# # CRM chr16	90338345
# # CRM chr17	83257441
# # CRM chr18	80373285
# # CRM chr19	58617616
# # CRM chr20	64444167
# # CRM chr21	46709983
# # CRM chr22	50818468
# # CRM chrX	156040895
# # CRM chrY	57227415
# # Mapped	reads count by iteration
# # MAPPED 1 5939379
# # MAPPED 2 4357130
# NS500645:59:HCL32BGXY:1:11101:10000:16279	chr10	88619681	0	75	88619497	88630956
# NS500645:59:HCL32BGXY:1:11101:10000:8112~2~	chr3	36464657	0	59	36464653	36465449
# NS500645:59:HCL32BGXY:1:11101:10002:9093	chr18	38400052	0	75	38399590	38401951
# NS500645:59:HCL32BGXY:1:11101:10002:9922	chrX	72292745	0	75	72292652	72295414
# NS500645:59:HCL32BGXY:1:11101:10003:18293	chrX	97506643	1	75	97500610	97506901
# NS500645:59:HCL32BGXY:1:11101:10003:3068	chr5	136124487	0	54	136124435	136125063|||NS500645:59:HCL32BGXY:1:11101:10003:3068~2~	chr5	94858630	1	23	94854766	94858631
# NS500645:59:HCL32BGXY:1:11101:10003:5939	chr10	77662769	0	25	77662746	77663539|||NS500645:59:HCL32BGXY:1:11101:10003:5939~2~	chr10	75728767	1	52	75727775	75728768
# NS500645:59:HCL32BGXY:1:11101:10004:10267	chr5	174448741	0	75	174448608	174454958
# NS500645:59:HCL32BGXY:1:11101:10004:12135~2~	chr2	154442512	1	57	154440609	154442513
# NS500645:59:HCL32BGXY:1:11101:10004:12614	chr15	70317499	1	48	70300434	70317542|||NS500645:59:HCL32BGXY:1:11101:10004:12614~2~	chr15	69367663	0	29	69367659	69373389
# NS500645:59:HCL32BGXY:1:11101:10004:16728	chr15	58911952	0	65	58911889	58917164
# NS500645:59:HCL32BGXY:1:11101:10004:8658	chr7	17547237	0	75	17547130	17551163
# NS500645:59:HCL32BGXY:1:11101:10005:11853	chr1	3903170	0	52	3903120	3905104|||NS500645:59:HCL32BGXY:1:11101:10005:11853~2~	chr1	3606375	0	25	3606371	3614620
# NS500645:59:HCL32BGXY:1:11101:10005:12121	chrX	29671880	1	75	29671038	29672844
# NS500645:59:HCL32BGXY:1:11101:10005:12688	chr3	42493705	0	75	42493608	42504262
# NS500645:59:HCL32BGXY:1:11101:10006:5162~2~	chr1	53918107	1	58	53917457	53918108
# NS500645:59:HCL32BGXY:1:11101:10007:3506	chr1	73128446	1	75	73125328	73128558
# NS500645:59:HCL32BGXY:1:11101:10007:9400	chr10	92228001	1	75	92222156	92235741
# NS500645:59:HCL32BGXY:1:11101:10009:12190	chr19	51025823	1	75	51019756	51025890
# NS500645:59:HCL32BGXY:1:11101:10009:19353	chr11	20788399	1	75	20786718	20788477
# NS500645:59:HCL32BGXY:1:11101:10010:10109	chr5	24801432	1	75	24793887	24801535
# NS500645:59:HCL32BGXY:1:11101:10010:18735	chr17	78482797	1	75	78480951	78482886

# %%
from pytadbit.mapping import get_intersection

# %%
! mkdir -p results/HindIII/03_filtering

# %%
get_intersection('results/HindIII/02_parsing/reads1_HindIII.tsv', 
                  'results/HindIII/02_parsing/reads2_HindIII.tsv', 
                 'results/HindIII/03_filtering/reads12.tsv')
# Out:
# (8177566, {2: 2416754, 3: 139110, 4: 2})

# %%
! head -n50 results/HindIII/03_filtering/reads12.tsv
# Out:
# # CRM chr1	248956422
# # CRM chr2	242193529
# # CRM chr3	198295559
# # CRM chr4	190214555
# # CRM chr5	181538259
# # CRM chr6	170805979
# # CRM chr7	159345973
# # CRM chr8	145138636
# # CRM chr9	138394717
# # CRM chr10	133797422
# # CRM chr11	135086622
# # CRM chr12	133275309
# # CRM chr13	114364328
# # CRM chr14	107043718
# # CRM chr15	101991189
# # CRM chr16	90338345
# # CRM chr17	83257441
# # CRM chr18	80373285
# # CRM chr19	58617616
# # CRM chr20	64444167
# # CRM chr21	46709983
# # CRM chr22	50818468
# # CRM chrX	156040895
# # CRM chrY	57227415
# NS500645:59:HCL32BGXY:1:11102:26481:1379	chr1	1001140	1	75	992015	1001575	chr1	1001256	0	75	992015	1001575
# NS500645:59:HCL32BGXY:1:12110:26115:5745	chr1	1001324	1	75	992015	1001575	chr21	46033968	0	75	46030463	46041407
# NS500645:59:HCL32BGXY:1:13206:7009:15464~2~	chr1	1007037	1	27	1001575	1007038	chr1	1007222	0	75	1007038	1008297
# NS500645:59:HCL32BGXY:1:12104:17437:2197~2~	chr1	1007037	1	63	1001575	1007038	chr1	1007243	0	75	1007038	1008297

# %%
from pytadbit.mapping.analyze import plot_distance_vs_interactions

# %%
plot_distance_vs_interactions('results/HindIII/03_filtering/reads12.tsv', resolution=100000, max_diff=1000, show=True)
# Out:
# ((-0.88265018662076211, 5.9164938010086949, -0.99863993019479413),
#  (-1.3501559560452454, 6.9658028500495099, -0.99882570064420828),
#  (-1.0587521964219113, 5.9115998331601851, -0.97867093398859228))

# %%
from pytadbit.mapping.analyze import plot_genomic_distribution

# %%
plot_genomic_distribution('results/HindIII/03_filtering/reads12.tsv', resolution=500000, show=True)

# %%
from pytadbit.mapping.analyze import hic_map

# %%
hic_map('results/HindIII/03_filtering/reads12.tsv', resolution=1000000, show=True)

# %%
from pytadbit.mapping.analyze import insert_sizes

# %%
insert_sizes('results/HindIII/03_filtering/reads12.tsv', show=True, nreads=100000)
# Out:
# [174.0, 617.01000000000931]

# %%
from pytadbit.mapping.filter import filter_reads

# %%
filter_reads('results/HindIII/03_filtering/reads12.tsv', max_molecule_length=750, min_dist_to_re=500)
# Out:
# Filtered reads (and percentage of total):
#
#      Mapped both                :     13706641 (100.00%)
#   -----------------------------------------------------
#    1- self-circle               :        37367 (  0.27%)
#    2- dangling-end              :       659487 (  4.81%)
#    3- error                     :        37387 (  0.27%)
#    4- extra dangling-end        :      3773374 ( 27.53%)
#    5- too close from RES        :      3277165 ( 23.91%)
#    6- too short                 :       296844 (  2.17%)
#    7- too large                 :         1842 (  0.01%)
#    8- over-represented          :       409496 (  2.99%)
#    9- duplicated                :       324435 (  2.37%)
#   10- random breaks             :       967791 (  7.06%)
# {1: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_self-circle.tsv',
#   'name': 'self-circle',
#   'reads': 37367},
#  2: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_dangling-end.tsv',
#   'name': 'dangling-end',
#   'reads': 659487},
#  3: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_error.tsv',
#   'name': 'error',
#   'reads': 37387},
#  4: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_extra_dangling-end.tsv',
#   'name': 'extra dangling-end',
#   'reads': 3773374},
#  5: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_too_close_from_RES.tsv',
#   'name': 'too close from RES',
#   'reads': 3277165},
#  6: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_too_short.tsv',
#   'name': 'too short',
#   'reads': 296844},
#  7: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_too_large.tsv',
#   'name': 'too large',
#   'reads': 1842},
#  8: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_over-represented.tsv',
#   'name': 'over-represented',
#   'reads': 409496},
#  9: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_duplicated.tsv',
#   'name': 'duplicated',
#   'reads': 324435},
#  10: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_random_breaks.tsv',
#   'name': 'random breaks',
#   'reads': 967791}}

# %%
masked = {1: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_self-circle.tsv',
  'name': 'self-circle',
  'reads': 37367},
 2: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_dangling-end.tsv',
  'name': 'dangling-end',
  'reads': 659487},
 3: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_error.tsv',
  'name': 'error',
  'reads': 37387},
 4: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_extra_dangling-end.tsv',
  'name': 'extra dangling-end',
  'reads': 3773374},
 5: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_too_close_from_RES.tsv',
  'name': 'too close from RES',
  'reads': 3277165},
 6: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_too_short.tsv',
  'name': 'too short',
  'reads': 296844},
 7: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_too_large.tsv',
  'name': 'too large',
  'reads': 1842},
 8: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_over-represented.tsv',
  'name': 'over-represented',
  'reads': 409496},
 9: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_duplicated.tsv',
  'name': 'duplicated',
  'reads': 324435},
 10: {'fnam': 'results/HindIII/03_filtering/reads12.tsv_random_breaks.tsv',
  'name': 'random breaks',
  'reads': 967791}}

# %%
from pytadbit.mapping.filter import apply_filter

# %%
apply_filter('results/HindIII/03_filtering/reads12.tsv', 'results/HindIII/03_filtering/reads12_valid.tsv', masked, filters=[1,2,3,4,9,10])
# Out:
#     saving to file 8481968 reads without .
# 8481968

# %%
ls
# Out:
# 00_fstq_QC.ipynb  learning_python.ipynb  text2.txt
# 01_Mapping.ipynb  results/               text.txt

# %%
from pytadbit.parsers.hic_parser import load_hic_data_from_reads

# %%
r_enz_1 = 'HindIII'
r_enz_2 = 'MboI'
reso = 1000000

# %%
hic_data_1 = load_hic_data_from_reads(
    'results/{0}/03_filtering/valid_reads12_{0}.tsv'.format(r_enz_1),
    reso)
hic_data_2 = load_hic_data_from_reads(
    'results/{0}/03_filtering/valid_reads12_{0}.tsv'.format(r_enz_2),
    reso)

# %%
hic_data_1.filter_columns(draw_hist=True, min_count=10, by_mean=True)
hic_data_2.filter_columns(draw_hist=True, min_count=10, by_mean=True)
# Out:
# WARNING: removing columns having less than 20 counts:
#    124   127   128   129   130   131   132   133   134   135   136   137   138   139   140   141   142   143   742   931
#    932  1295  1563  1567  1571  1572  1586  1587  1588  1589  1590  1591  1592  1593  1594  1595  1596  1597  1598  1599
#   1600  1601  1721  1867  1868  2085  2086  2087  2088  2089  2090  2091  2092  2093  2094  2095  2096  2097  2098  2099
#   2100  2101  2102  2200  2201  2202  2203  2204  2205  2206  2207  2208  2209  2210  2211  2212  2213  2214  2215  2216
#           7182.960        8205.508       11988.885    7   0.46108
#           6012.410        8247.864        9191.391    8   0.27103
#           7526.569        8276.798       10683.760    9   0.29081
#           6714.214        8297.160        8971.088   10   0.19078
# rescaling to factor 1
#   - getting the sum of the matrix
#     => 2837.829
#   - rescaling biases
# iterative correction
#   - copying matrix
#   - computing baises
#            138.000         790.629        4403.000    0   4.56898
#            399.372         861.843        2175.062    1   1.52373
#            436.749         893.671        1220.721    2   0.51129
#            739.963         908.526        1522.920    3   0.67625
#            613.184         916.395        1058.900    4   0.33087
#            823.897         920.596        1246.005    5   0.35348
#            728.392         923.008         999.354    6   0.21085
#            870.724         924.391        1109.283    7   0.20001
#            801.121         925.223         966.047    8   0.13413
#            896.220         925.721        1036.769    9   0.11996
#            846.201         926.030         949.790   10   0.08620
# rescaling to factor 1
#   - getting the sum of the matrix
#     => 2836.582
#   - rescaling biases

# %%
from pytadbit.mapping.analyze import hic_map

hic_map(hic_data_1, normalized=True, focus='chr18', show=True)
hic_map(hic_data_2, normalized=True, focus='chr18', show=True)

# %%
from cPickle import dump

# %%
! mkdir -p results/$r_enz_1/04_normalizing
! mkdir -p results/$r_enz_2/04_normalizing

# %%
out = open('results/{1}/04_normalizing/biases_{0}_{1}.pick'.format(reso, r_enz_1), 'w')
dump(hic_data_1.bias, out)
out.close()
out = open('results/{1}/04_normalizing/biases_{0}_{1}.pick'.format(reso, r_enz_2), 'w')
dump(hic_data_2.bias, out)
out.close()

# %%
out = open('results/{1}/04_normalizing/bad_columns_{0}_{1}.pick'.format(reso, r_enz_1), 'w')
dump(hic_data_1.bads, out)
out.close()
out = open('results/{1}/04_normalizing/bad_columns_{0}_{1}.pick'.format(reso, r_enz_2), 'w')
dump(hic_data_2.bads, out)
out.close()

# %%
! dryhic3.r results/HindIII/03_filtering/valid_reads12_HindIII.tsv \
       results/HindIII/04_normalizing/bad_columns_1000000_HindIII.pick \
       HindIII hg38 1000000 results/HindIII/04_normalizing/biases_dryhic_1000000_HindIII.pick
# Out:
# Getting contacts
# Read 8626149 rows and 2 (of 13) columns from 0.969 GB file in 00:00:06
# Getting genomic features
# Merging info
# Getting bad bins
# Computing biases
# Storing results

# %%
! dryhic3.r results/MboI/03_filtering/valid_reads12_MboI.tsv \
       results/MboI/04_normalizing/bad_columns_1000000_MboI.pick \
       MboI hg38 1000000 results/MboI/04_normalizing/biases_dryhic_1000000_MboI.pick
# Out:
# Getting contacts
# Getting genomic features
# Merging info
# Getting bad bins
# Computing biases
# Storing results

# %%
bias_dry_path = 'results/{1}/04_normalizing/biases_dryhic_{0}_{1}.tsv'

hic_data_1.bias = dict([(int(l.split()[0]), float(l.split()[1])) for l in open(bias_dry_path.format(reso, 'HindIII'))])
hic_data_2.bias = dict([(int(l.split()[0]), float(l.split()[1])) for l in open(bias_dry_path.format(reso, 'MboI'))])

# %%
hic_map(hic_data_1, normalized=True, focus='chr18', show=True)
hic_map(hic_data_2, normalized=True, focus='chr18', show=True)
