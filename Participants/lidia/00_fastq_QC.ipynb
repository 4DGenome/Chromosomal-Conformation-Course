# %%
# !ls
# Out:
# 00_fastq_QC.ipynb  learning_python.ipynb

# %%
# !pwd
# Out:
# /home/student/Notebooks/lidia

# %%
pwd
# Out:
# u'/home/student/Notebooks/lidia'

# %%
# !head
# Out:
# ^C

# %%
# !head/media/storage/FASTQs
# Out:
# /bin/sh: 1: head/media/storage/FASTQs: not found

# %%
# !head/media/storage/FASTQs/
# Out:
# /bin/sh: 1: head/media/storage/FASTQs/: not found

# %%
# !head/media/storage/FASTQs/K562_HindIII_1.fastq
# Out:
# /bin/sh: 1: head/media/storage/FASTQs/K562_HindIII_1.fastq: not found

# %%
! wc -l/media/storage/FASTQs/K562_HindIII_1.fastq
# Out:
# wc: invalid option -- '/'
# Try 'wc --help' for more information.

# %%
! wc -l /media/storage/FASTQs/K562_HindIII_1.fastq
# Out:
# 40000000 /media/storage/FASTQs/K562_HindIII_1.fastq

# %%
! wc -l /media/storage/rage/rage/rage/FASTQs/STQs/STQs/STQs/Qs/Qs/Qs/K562_HindIII_1.fastq
# Out:
# 40000000 /media/storage/FASTQs/K562_HindIII_1.fastq

# %% [markdown]
# # FASTQ quality check using TADbit

# %%
from pytadbid.utils.fastq_utils import quality_plot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-61e268094f25> in <module>()
# ----> 1 from pytadbid.utils.fastq_utils import quality_plot
#
# ImportError: No module named pytadbid.utils.fastq_utils

# %%
quality_plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-173939527937> in <module>()
# ----> 1 quality_plot()
#
# NameError: name 'quality_plot' is not defined

# %%
from pytadbit.utils.fastq_utils import quality_plot

# %%
quality_plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-173939527937> in <module>()
# ----> 1 quality_plot()
#
# TypeError: quality_plot() takes at least 1 argument (0 given)

# %%
quality_plot('/media/storage/FASTQs/K562_HindIII_1.fastq', r_enz='HindIII', nreads=1000000)
# Out:
# (0.8355, 28.7747)

# %%
quality_plot('/media/storage/FASTQs/K562_HindIII_2.fastq', r_enz='HindIII', nreads=1000000)
# Out:
# (0.8117, 27.4062)

# %%
quality_plot('/media/storage/FASTQs/K562_MboI_1.fastq', r_enz='MboI', nreads=1000000)
# Out:
# (2.7736, 35.1285)

# %%
from py
